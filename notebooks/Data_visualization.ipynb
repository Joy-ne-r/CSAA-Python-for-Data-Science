# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Introducing data visualization day 3

# %%
#Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Line plot
x = np.linspace(0,0.9,12)
y = x**2 + (4*x - 2.1)
plt.plot(x,y);
plt.xlabel("Some random numbers")
plt.ylabel("Function of some random numbers")
plt.title("Change in some random numbers")
# Out:
# Text(0.5, 1.0, 'Change in some random numbers')

# %%
#Scatter plot
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,100,86,103,87,94,78,77,85,86]
plt.scatter(x,y);
plt.xlabel("Student ID'S")
plt.ylabel("WScores")
plt.title("Score of Students in National exams")
# Out:
# Text(0.5, 1.0, 'Score of Students in National exams')

# %%
#Bar Plot
categories = ["A","B","C","D"]
values = [5,7,3,8]
plt.bar(categories, values)
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Number of items bought per day")
# Out:
# Text(0.5, 1.0, 'Number of items bought per day')

# %%
#create 4 sub plots for all the graphs

# %%
#Histogram
import numpy as np
data = np.random.normal(0,1,100)
plt.hist(data, bins=20)
plt.ylabel("Frequency")
plt.xlabel("Values")
plt.title("The intensity of sound waves")
# Out:
# Text(0.5, 1.0, 'The intensity of sound waves')

# %%
plt.style.use("ggplot")
#plt.style.use("dark_background")

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

#Line Graph
x = np.linspace(0,0.9,12)
y = x**2 + (4*x - 2.1)
axs[0, 0].plot(x, y, color='blue')
axs[0, 0].set_title("Change in some random numbers")
axs[0, 0].set_xlabel("Some random numbers")
axs[0, 0].set_ylabel("Function of some random numbers")

#Scatter plot
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,100,86,103,87,94,78,77,85,86]
axs[0, 1].scatter(x,y,color="orange");
axs[0, 1].set_title("Students in National exams")
axs[0, 1].set_xlabel("Student ID'S")
axs[0, 1].set_ylabel("Scores")

#Bar Graph
categories = ["A","B","C","D"]
values = [5,7,3,8]
axs[1, 0].bar(categories, values, color= "pink")
axs[1, 0].set_title("Number of items bought per day")
axs[1, 0].set_xlabel("Categories")
axs[1, 0].set_ylabel("Values")

#Histogram
data = np.random.normal(0,1,100)
axs[1, 1].hist(data, bins=10,color="green")
axs[1, 1].set_title("The intensity of sound waves")
axs[1, 1].set_xlabel("Values")
axs[1, 1].set_ylabel("Frequency")

# Adjust layout to prevent overlapping titles/labels
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # Data Visualization Day 4

# %%
#Load the data
gapminder_data = pd.read_csv("../data/gapminder.csv")
gapminder_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           1704 non-null   object
#  1   continent         1704 non-null   object
#  2   year              1704 non-null   int64
#  3   life_exp          1704 non-null   float64
#  4   pop               1704 non-null   float64
#  5   gdp_per_cap       1704 non-null   float64
#  6   infant_mortality  1224 non-null   float64
#  7   fertility         1330 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 106.6+ KB

# %%
gapminder_data.head()
# Out:
#        country continent  year  life_exp         pop  gdp_per_cap  \
# 0  Afghanistan      Asia  1952    28.801   8425333.0   779.445314
# 1  Afghanistan      Asia  1957    30.332   9240934.0   820.853030
# 2  Afghanistan      Asia  1962    31.997  10267083.0   853.100710
# 3  Afghanistan      Asia  1967    34.020  11537966.0   836.197138
# 4  Afghanistan      Asia  1972    36.088  13079460.0   739.981106
#
#    infant_mortality  fertility
# 0               NaN        NaN
# 1               NaN        NaN
# 2               NaN        NaN
# 3               NaN        NaN
# 4               NaN        NaN

# %%
gapminder_data.describe()
# Out:
#              year     life_exp           pop    gdp_per_cap  infant_mortality  \
# count  1704.00000  1704.000000  1.704000e+03    1704.000000       1224.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081         63.709665
# std      17.26533    12.917107  1.061579e+08    9857.454543         50.454764
# min    1952.00000    23.599000  6.001100e+04     241.165876          2.200000
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309         18.700000
# 50%    1979.50000    60.712500  7.023596e+06    3531.846988         52.550000
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346        101.675000
# max    2007.00000    82.603000  1.318683e+09  113523.132900        226.000000
#
#          fertility
# count  1330.000000
# mean      4.407105
# std       2.084137
# min       0.920000
# 25%       2.350000
# 50%       4.500000
# 75%       6.347500
# max       8.420000

# %% [markdown]
# # Scatter plots

# %%
#Finding the highest year in a column
gapminder_data["year"].max()
# Out:
# 2007

# %%
#Changes the year to 2003
#gapminder_data["year"]= 2003

# %%
#Info for a specific country
gapminder_data["country"] =="Kenya"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
#gapminder_data["year"]

#gapminder_data["country"]==Kenya]
mask_2002 = gapminder_data["year"]==2002
mask_2002
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702     True
# 1703    False
# Name: year, Length: 1704, dtype: bool

# %%
gapminder_data[(gapminder_data["year"] == 2002) & (gapminder_data["country"] =="Kenya")]
# Out:
#     country continent  year  life_exp         pop  gdp_per_cap  \
# 826   Kenya    Africa  2002    50.992  31386842.0  1287.514732
#
#      infant_mortality  fertility
# 826              62.2       4.99

# %%
gapminder_mask_2002 = gapminder_data[mask_2002]
gapminder_mask_2002
# Out:
#                  country continent  year  life_exp         pop  gdp_per_cap  \
# 10           Afghanistan      Asia  2002    42.129  25268405.0   726.734055
# 22               Albania    Europe  2002    75.651   3508512.0  4604.211737
# 34               Algeria    Africa  2002    70.994  31287142.0  5288.040382
# 46                Angola    Africa  2002    41.003  10866106.0  2773.287312
# 58             Argentina  Americas  2002    74.340  38331121.0  8797.640716
# ...                  ...       ...   ...       ...         ...          ...
# 1654             Vietnam      Asia  2002    73.017  80908147.0  1764.456677
# 1666  West Bank and Gaza      Asia  2002    72.370   3389578.0  4515.487575
# 1678         Yemen, Rep.      Asia  2002    60.308  18701257.0  2234.820827
# 1690              Zambia    Africa  2002    39.193  10595811.0  1071.613938
# 1702            Zimbabwe    Africa  2002    39.989  11926563.0   672.038623
#
#       infant_mortality  fertility
# ...

# %%
#To display all the years in the data
gapminder_data["year"].unique()

# %%
#To get the data of a specific year
gapminder_2002 = gapminder_data[gapminder_data ["year"]==2002]
gapminder_2002
# Out:
#                  country continent  year  life_exp         pop  gdp_per_cap  \
# 10           Afghanistan      Asia  2002    42.129  25268405.0   726.734055
# 22               Albania    Europe  2002    75.651   3508512.0  4604.211737
# 34               Algeria    Africa  2002    70.994  31287142.0  5288.040382
# 46                Angola    Africa  2002    41.003  10866106.0  2773.287312
# 58             Argentina  Americas  2002    74.340  38331121.0  8797.640716
# ...                  ...       ...   ...       ...         ...          ...
# 1654             Vietnam      Asia  2002    73.017  80908147.0  1764.456677
# 1666  West Bank and Gaza      Asia  2002    72.370   3389578.0  4515.487575
# 1678         Yemen, Rep.      Asia  2002    60.308  18701257.0  2234.820827
# 1690              Zambia    Africa  2002    39.193  10595811.0  1071.613938
# 1702            Zimbabwe    Africa  2002    39.989  11926563.0   672.038623
#
#       infant_mortality  fertility
# ...

# %%
#creating a figure object
fig, axes = plt.subplots(figsize=(8,6))

# %%
#Pot life expectancy as a function of gdp_per_cap
gapminder_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           1704 non-null   object
#  1   continent         1704 non-null   object
#  2   year              1704 non-null   int64
#  3   life_exp          1704 non-null   float64
#  4   pop               1704 non-null   float64
#  5   gdp_per_cap       1704 non-null   float64
#  6   infant_mortality  1224 non-null   float64
#  7   fertility         1330 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 106.6+ KB

# %%
#Plotting a graph of gdp_per_cap vs life_exp for 2002
fig, axes = plt.subplots(figsize=(8,6))
plt.scatter(gapminder_2002["gdp_per_cap"],gapminder_2002["life_exp"],color="purple") #alpha=0.5
plt.xlabel("gdp_per_cap")
plt.ylabel("life_exp")
plt.title("Life Expectancy as a function of GDP Per Capita for 2002")
plt.show()

# %%
gapminder_Kenya= gapminder_data["country"] =="Kenya"
gapminder_Kenya
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
#Getting the info the data of Kenya
gapminder_Kenya = gapminder_data[gapminder_data ["country"]=="Kenya"]
gapminder_Kenya
# Out:
#     country continent  year  life_exp         pop  gdp_per_cap  \
# 816   Kenya    Africa  1952    42.270   6464046.0   853.540919
# 817   Kenya    Africa  1957    44.686   7454779.0   944.438315
# 818   Kenya    Africa  1962    47.949   8678557.0   896.966373
# 819   Kenya    Africa  1967    50.654  10191512.0  1056.736457
# 820   Kenya    Africa  1972    53.559  12044785.0  1222.359968
# 821   Kenya    Africa  1977    56.155  14500404.0  1267.613204
# 822   Kenya    Africa  1982    58.766  17661452.0  1348.225791
# 823   Kenya    Africa  1987    59.339  21198082.0  1361.936856
# 824   Kenya    Africa  1992    59.285  25020539.0  1341.921721
# 825   Kenya    Africa  1997    54.407  28263827.0  1360.485021
# 826   Kenya    Africa  2002    50.992  31386842.0  1287.514732
# 827   Kenya    Africa  2007    54.110  35610177.0  1463.249282
#
#      infant_mortality  fertility
# 816               NaN        NaN
# 817               NaN        NaN
# 818             109.9       8.04
# ...

# %%
#Getting the info the data of Kenya
gapminder_Kenya = gapminder_data[gapminder_data ["country"]=="Kenya"]
gapminder_Kenya

#Plotting a graph of gdp_per_cap vs life_exp for Kenya
fig, axes = plt.subplots()
plt.scatter(gapminder_Kenya["gdp_per_cap"],gapminder_Kenya["life_exp"],color="red",) #alpha=0.5
axes.set_xlabel("gdp_per_cap")
axes.set_ylabel("life_exp")
plt.suptitle("Life Expectancy as a function of GDP Per Capita for Kenya",fontname="Arial", size=16)
plt.title("From Gapminder data", loc="left")

#axes.set_ylim(bottom=0);

#Displaying the plot
plt.show()

# %%
#Save the figure
fig.savefig("../data/output/gapminder_Kenya.png")

# %%
#Getting the info the data of Kenya
gapminder_Kenya = gapminder_data[gapminder_data ["country"]=="Kenya"]
gapminder_Kenya

#Plotting a graph of gdp_per_cap vs life_exp for Kenya
fig, axes = plt.subplots()
plt.scatter(gapminder_2002["gdp_per_cap"],gapminder_2002["life_exp"],color="maroon",) #alpha=0.5
axes.set_xlabel("gdp_per_cap")
axes.set_ylabel("life_exp")
plt.suptitle("Life Expectancy as a function of GDP Per Capita for 2002 ",fontname="Arial", size=16)
plt.title("From Gapminder data", loc="left")

#axes.set_ylim(bottom=0);-chnging the scale on y-axis

#Displaying the plot
plt.show()

# %%
#Save the figure
fig.savefig("../data/output/gapminder_2002.png")

# %% [markdown]
# # Plotting with Seabon

# %%
import seaborn as sns

#Load a data set
#gapminder_sns = sns.load_dataset("../data/gapminder.cvs")
#Import the dataset of gapminder_Kenya
#Creating the plot
sns.relplot(
#sns.scatterplot(
    data = gapminder_2002,
    x = "gdp_per_cap", y ="life_exp",
    hue = "continent", size="pop",sizes= (200,2000),
)

# %%
#Import the dataset of gapminder_Kenya
sns.relplot(
#sns.scatterplot(
    data = gapminder_Kenya,
    x = "gdp_per_cap", y ="life_exp",
     hue = "year",size="pop",sizes= (20,1000),
)
    #legend = plt.legend(loc ='best', frameon = True,
     #                   shodow=True,borderpad=1)
    #legend.get_frame().set_alpha(0.9)  # Slightly transparent
    #plt.setp(legend.get_texts(), fontsize='10', fontname='Arial')  # Customize the font of the legend texts

# %%
sns.lineplot(
#sns.scatterplot(
    data = gapminder_Kenya, color = "green",
    x = "gdp_per_cap", y ="life_exp",marker = "x",
)
# Out:
# <Axes: xlabel='gdp_per_cap', ylabel='life_exp'>

# %%
sns.lineplot(
#sns.scatterplot(
    data = gapminder_Kenya, color = "pink",
    x = "gdp_per_cap", y ="life_exp",marker = "o",
)
# Out:
# <Axes: xlabel='gdp_per_cap', ylabel='life_exp'>
