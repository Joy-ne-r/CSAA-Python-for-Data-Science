# %% [markdown]
# # Data Wrangling

# %% [markdown]
# # Introducing data wrangling day 3

# %%
#Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the data
bike_data = pd.read_csv("../data/bikes.csv")

# %%
#Displaying the first five rows
bike_data.head()
# Out:
#          date  real_temperature  feel_temperature  humidity  wind_speed  \
# 0  04/01/2015              2.75              0.00     93.00    7.500000
# 1  05/01/2015              9.00              7.25     81.50    8.854167
# 2  06/01/2015              8.00              5.75     79.75   16.000000
# 3  07/01/2015              9.00              5.50     81.00   19.760870
# 4  08/01/2015              9.00              6.75     79.50   20.479167
#
#        weather_code  is_holiday  is_weekend  season  count
# 0     broken_clouds       False        True  winter   9234
# 1     broken_clouds       False       False  winter  20372
# 2             clear       False       False  winter  20613
# 3  scattered_clouds       False       False  winter  21064
# 4              rain       False       False  winter  15601

# %%
#Getting the data information
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              730 non-null    object
#  1   real_temperature  730 non-null    float64
#  2   feel_temperature  657 non-null    float64
#  3   humidity          730 non-null    float64
#  4   wind_speed        730 non-null    float64
#  5   weather_code      679 non-null    object
#  6   is_holiday        730 non-null    bool
#  7   is_weekend        730 non-null    bool
#  8   season            694 non-null    object
#  9   count             730 non-null    int64
# dtypes: bool(2), float64(4), int64(1), object(3)
# memory usage: 47.2+ KB

# %%
#Getting info of the statistical numerical values 
bike_data.describe()
# Out:
#        real_temperature  feel_temperature    humidity  wind_speed  \
# count        730.000000        657.000000  730.000000  730.000000
# mean          12.481849         11.506088   73.034932   15.954665
# std            5.086471          6.110233   10.245519    6.221691
# min            0.250000         -2.000000   40.500000    2.770833
# 25%            8.812500          6.250000   65.250000   11.208333
# 50%           12.625000         12.500000   73.750000   15.166667
# 75%           16.187500         16.000000   80.750000   19.906250
# max           28.500000         29.000000  100.000000   41.900000
#
#               count
# count    730.000000
# mean   27268.454795
# std     8607.700254
# min     4869.000000
# 25%    21940.750000
# 50%    27011.500000
# 75%    33431.250000
# max    72504.000000

# %%
#Getting the shape(rows and columns) of the data
bike_data.shape
# Out:
# (730, 10)

# %%
##Getting the impormation of the last five rows
bike_data.tail()
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 725  30/12/2016              4.00              1.00     100.0    9.000000
# 726  31/12/2016              7.50              5.00      90.0   13.312500
# 727  01/01/2017              7.00              4.75      90.0   14.125000
# 728  02/01/2017              3.25              0.50      82.5   11.166667
# 729  03/01/2017              4.50              0.50      81.0   18.937500
#
#     weather_code  is_holiday  is_weekend  season  count
# 725       cloudy       False       False  winter  11566
# 726       cloudy       False        True  winter  11424
# 727         rain       False        True  winter   6421
# 728        clear        True       False  winter  11823
# 729        clear       False       False  winter  19436

# %%
#Getting the impormation of a number of samples
bike_data.sample(10)
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 102  16/04/2015             11.00             11.00     65.75   19.625000
# 235  27/08/2015             16.00             16.00     80.00   17.500000
# 159  12/06/2015             18.25             18.25     69.00   12.208333
# 420  28/02/2016              5.00              2.00     69.00   19.604167
# 29   02/02/2015              1.25             -2.00     65.75   12.625000
# 480  28/04/2016              9.00               NaN     63.00   16.958333
# 100  14/04/2015             15.50             15.50     62.00   17.166667
# 669  04/11/2016              9.00               NaN     79.00    9.229167
# 517  04/06/2016             15.75             15.75     88.00    8.604167
# 168  21/06/2015             17.25             17.25     58.25   23.041667
#
#          weather_code  is_holiday  is_weekend  season  count
# 102             clear       False       False  spring  30489
# ...

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              730 non-null    object
#  1   real_temperature  730 non-null    float64
#  2   feel_temperature  657 non-null    float64
#  3   humidity          730 non-null    float64
#  4   wind_speed        730 non-null    float64
#  5   weather_code      679 non-null    object
#  6   is_holiday        730 non-null    bool
#  7   is_weekend        730 non-null    bool
#  8   season            694 non-null    object
#  9   count             730 non-null    int64
# dtypes: bool(2), float64(4), int64(1), object(3)
# memory usage: 47.2+ KB

# %%
#Displaying the info of the feel temp
feel_temp = bike_data["feel_temperature"]
feel_temp
# Out:
# 0      0.00
# 1      7.25
# 2      5.75
# 3      5.50
# 4      6.75
#        ...
# 725    1.00
# 726    5.00
# 727    4.75
# 728    0.50
# 729    0.50
# Name: feel_temperature, Length: 730, dtype: float64

# %%
#Displaying the info of the feel temp and real temp
temp = bike_data[["real_temperature","feel_temperature"]]
temp
# Out:
#      real_temperature  feel_temperature
# 0                2.75              0.00
# 1                9.00              7.25
# 2                8.00              5.75
# 3                9.00              5.50
# 4                9.00              6.75
# ..                ...               ...
# 725              4.00              1.00
# 726              7.50              5.00
# 727              7.00              4.75
# 728              3.25              0.50
# 729              4.50              0.50
#
# [730 rows x 2 columns]

# %%
#Make copy of the orginal data
toy_bikes = bike_data.copy()

# %%
toy_bikes.head()
# Out:
#          date  real_temperature  feel_temperature  humidity  wind_speed  \
# 0  04/01/2015              2.75              0.00     93.00    7.500000
# 1  05/01/2015              9.00              7.25     81.50    8.854167
# 2  06/01/2015              8.00              5.75     79.75   16.000000
# 3  07/01/2015              9.00              5.50     81.00   19.760870
# 4  08/01/2015              9.00              6.75     79.50   20.479167
#
#        weather_code  is_holiday  is_weekend  season  count
# 0     broken_clouds       False        True  winter   9234
# 1     broken_clouds       False       False  winter  20372
# 2             clear       False       False  winter  20613
# 3  scattered_clouds       False       False  winter  21064
# 4              rain       False       False  winter  15601

# %%
toy_bikes.tail()
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 725  30/12/2016              4.00              1.00     100.0    9.000000
# 726  31/12/2016              7.50              5.00      90.0   13.312500
# 727  01/01/2017              7.00              4.75      90.0   14.125000
# 728  02/01/2017              3.25              0.50      82.5   11.166667
# 729  03/01/2017              4.50              0.50      81.0   18.937500
#
#     weather_code  is_holiday  is_weekend  season  count
# 725       cloudy       False       False  winter  11566
# 726       cloudy       False        True  winter  11424
# 727         rain       False        True  winter   6421
# 728        clear        True       False  winter  11823
# 729        clear       False       False  winter  19436

# %%
toy_bikes.sample(10)
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 729  03/01/2017              4.50              0.50     81.00   18.937500
# 606  01/09/2016             19.00             19.00     68.00   13.760870
# 377  16/01/2016              3.00              0.50     75.00    9.562500
# 15   19/01/2015              2.25              1.25     76.50    6.187500
# 559  16/07/2016             21.25             21.25     72.00   20.666667
# 181  04/07/2015             21.50             21.50     58.25   17.437500
# 55   28/02/2015              9.00              6.00     85.00   23.083333
# 496  14/05/2016             10.00              8.75     58.00   14.250000
# 650  16/10/2016             14.25             14.25     85.00   14.437500
# 213  05/08/2015             17.75               NaN     68.25   11.062500
#
#          weather_code  is_holiday  is_weekend  season  count
# 729             clear       False       False  winter  19436
# ...

# %%
#Check the number of missing enteries per column
toy_bikes.isnull().sum()
# Out:
# date                 0
# real_temperature     0
# feel_temperature    73
# humidity             0
# wind_speed           0
# weather_code        51
# is_holiday           0
# is_weekend           0
# season              36
# count                0
# dtype: int64

# %%
#Drop the missing entries but not parmanently
toy_bikes.dropna()
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 0    04/01/2015              2.75              0.00     93.00    7.500000
# 1    05/01/2015              9.00              7.25     81.50    8.854167
# 2    06/01/2015              8.00              5.75     79.75   16.000000
# 3    07/01/2015              9.00              5.50     81.00   19.760870
# 4    08/01/2015              9.00              6.75     79.50   20.479167
# ..          ...               ...               ...       ...         ...
# 725  30/12/2016              4.00              1.00    100.00    9.000000
# 726  31/12/2016              7.50              5.00     90.00   13.312500
# 727  01/01/2017              7.00              4.75     90.00   14.125000
# 728  02/01/2017              3.25              0.50     82.50   11.166667
# 729  03/01/2017              4.50              0.50     81.00   18.937500
#
#          weather_code  is_holiday  is_weekend  season  count
# ...

# %%
toy_bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              730 non-null    object
#  1   real_temperature  730 non-null    float64
#  2   feel_temperature  657 non-null    float64
#  3   humidity          730 non-null    float64
#  4   wind_speed        730 non-null    float64
#  5   weather_code      679 non-null    object
#  6   is_holiday        730 non-null    bool
#  7   is_weekend        730 non-null    bool
#  8   season            694 non-null    object
#  9   count             730 non-null    int64
# dtypes: bool(2), float64(4), int64(1), object(3)
# memory usage: 47.2+ KB

# %%
#Drops the missing entries permanently and write a new df to file
toy_bikes.dropna(inplace=True)

# %%
#Check the number of missing enteries per column
toy_bikes.isnull().sum()
# Out:
# date                0
# real_temperature    0
# feel_temperature    0
# humidity            0
# wind_speed          0
# weather_code        0
# is_holiday          0
# is_weekend          0
# season              0
# count               0
# dtype: int64

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              730 non-null    object
#  1   real_temperature  730 non-null    float64
#  2   feel_temperature  657 non-null    float64
#  3   humidity          730 non-null    float64
#  4   wind_speed        730 non-null    float64
#  5   weather_code      679 non-null    object
#  6   is_holiday        730 non-null    bool
#  7   is_weekend        730 non-null    bool
#  8   season            694 non-null    object
#  9   count             730 non-null    int64
# dtypes: bool(2), float64(4), int64(1), object(3)
# memory usage: 47.2+ KB

# %%
bike_imputted = bike_data.copy()

# %%
bike_imputted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              730 non-null    object
#  1   real_temperature  730 non-null    float64
#  2   feel_temperature  657 non-null    float64
#  3   humidity          730 non-null    float64
#  4   wind_speed        730 non-null    float64
#  5   weather_code      679 non-null    object
#  6   is_holiday        730 non-null    bool
#  7   is_weekend        730 non-null    bool
#  8   season            694 non-null    object
#  9   count             730 non-null    int64
# dtypes: bool(2), float64(4), int64(1), object(3)
# memory usage: 47.2+ KB

# %%
#Impute missing data for feel temeperature
#Calculate the mean of the column
mean_feel_temperature = bike_imputted["feel_temperature"].mean()

#Filling missing values
bike_temp_imputted = bike_imputted["feel_temperature"].fillna(mean_feel_temperature)
bike_temp_imputted.sample(10)
# Out:
# 25     -2.00
# 677     8.00
# 376     0.00
# 69      3.00
# 528    16.75
# 565    20.75
# 352    14.50
# 78      7.00
# 5      13.00
# 618    22.75
# Name: feel_temperature, dtype: float64

# %%
mean_feel_temperature
# Out:
# 11.506088280060883

# %%
bike_imputted["feel_temp_imputted"] = bike_imputted["feel_temperature"].fillna(mean_feel_temperature)
bike_imputted
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 0    04/01/2015              2.75              0.00     93.00    7.500000
# 1    05/01/2015              9.00              7.25     81.50    8.854167
# 2    06/01/2015              8.00              5.75     79.75   16.000000
# 3    07/01/2015              9.00              5.50     81.00   19.760870
# 4    08/01/2015              9.00              6.75     79.50   20.479167
# ..          ...               ...               ...       ...         ...
# 725  30/12/2016              4.00              1.00    100.00    9.000000
# 726  31/12/2016              7.50              5.00     90.00   13.312500
# 727  01/01/2017              7.00              4.75     90.00   14.125000
# 728  02/01/2017              3.25              0.50     82.50   11.166667
# 729  03/01/2017              4.50              0.50     81.00   18.937500
#
#          weather_code  is_holiday  is_weekend  season  count  \
# ...

# %%
#Calculate the average temp of the column
average_temperature = bike_imputted[["feel_temp_imputted","real_temperature"]].mean(axis=1)
average_temperature

#Creating a new column for the average temp
bike_imputted["average_temp"] = average_temperature

# %%
bike_imputted
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 0    04/01/2015              2.75              0.00     93.00    7.500000
# 1    05/01/2015              9.00              7.25     81.50    8.854167
# 2    06/01/2015              8.00              5.75     79.75   16.000000
# 3    07/01/2015              9.00              5.50     81.00   19.760870
# 4    08/01/2015              9.00              6.75     79.50   20.479167
# ..          ...               ...               ...       ...         ...
# 725  30/12/2016              4.00              1.00    100.00    9.000000
# 726  31/12/2016              7.50              5.00     90.00   13.312500
# 727  01/01/2017              7.00              4.75     90.00   14.125000
# 728  02/01/2017              3.25              0.50     82.50   11.166667
# 729  03/01/2017              4.50              0.50     81.00   18.937500
#
#          weather_code  is_holiday  is_weekend  season  count  \
# ...

# %%
bike_imputted.drop(columns=["real_temperature","feel_temperature","feel_temp_imputted"], inplace=True)
bike_imputted
# Out:
#            date  humidity  wind_speed      weather_code  is_holiday  \
# 0    04/01/2015     93.00    7.500000     broken_clouds       False
# 1    05/01/2015     81.50    8.854167     broken_clouds       False
# 2    06/01/2015     79.75   16.000000             clear       False
# 3    07/01/2015     81.00   19.760870  scattered_clouds       False
# 4    08/01/2015     79.50   20.479167              rain       False
# ..          ...       ...         ...               ...         ...
# 725  30/12/2016    100.00    9.000000            cloudy       False
# 726  31/12/2016     90.00   13.312500            cloudy       False
# 727  01/01/2017     90.00   14.125000              rain       False
# 728  02/01/2017     82.50   11.166667             clear        True
# 729  03/01/2017     81.00   18.937500             clear       False
#
#      is_weekend  season  count  average_temp
# 0          True  winter   9234         1.375
# 1         False  winter  20372         8.125
# ...

# %%
bike_imputted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          730 non-null    object
#  1   humidity      730 non-null    float64
#  2   wind_speed    730 non-null    float64
#  3   weather_code  679 non-null    object
#  4   is_holiday    730 non-null    bool
#  5   is_weekend    730 non-null    bool
#  6   season        694 non-null    object
#  7   count         730 non-null    int64
#  8   average_temp  730 non-null    float64
# dtypes: bool(2), float64(3), int64(1), object(3)
# memory usage: 41.5+ KB

# %%
#Fill the missing values with the median value in the column
#bike_imputted["feel_temperature"] = bike_imputed["feel_imputed"].fillna(bike median

# %%
#Fillinf missing values in season column using interpolation by padding
bike_imputted["season"].interpolate(method="pad",inplace=True)
# Out:
# C:\Users\HomePC\AppData\Local\Temp\ipykernel_15500\1546433791.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   bike_imputted["season"].interpolate(method="pad",inplace=True)
# C:\Users\HomePC\AppData\Local\Temp\ipykernel_15500\1546433791.py:2: FutureWarning: Series.interpolate with method=pad is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   bike_imputted["season"].interpolate(method="pad",inplace=True)

# %%
bike_imputted.isnull().sum()
# Out:
# date             0
# humidity         0
# wind_speed       0
# weather_code    51
# is_holiday       0
# is_weekend       0
# season           0
# count            0
# average_temp     0
# dtype: int64

# %%
values_per_season = bike_imputted["season"].value_counts()
values_per_season
# Out:
# season
# spring    185
# summer    184
# autumm    181
# winter    180
# Name: count, dtype: int64

# %% [markdown]
# # Day 4: Merging and Joining Data

# %%
#-q hides some info that you don't want to see
# !pip install -q openpyxl

# %%
#Load the data
titanic_data= pd.read_excel("../data/titanic.xlsx")
join_data1= pd.read_csv("../data/joining_data1.csv")
join_data2= pd.read_csv("../data/joining_data2.csv")
union_data= pd.read_csv("../data/union_data.csv")

# %%
# Explore the new datasets
join_data1
# Out:
#                name animal  age
# 0   Catalie Portman    cat    3
# 1      Pico de Gato    cat    5
# 2         Chewbarka    dog    1
# 3  Sir Isaac Mewton    cat    7
# 4                K9    cat   11
# 5         Arf Vader    dog    6

# %%
join_data2
# Out:
#                name  vaccinated
# 0   Catalie Portman        True
# 1      Pico de Gato        True
# 2         Chewbarka       False
# 3  Sir Isaac Mewton        True
# 4                K9       False
# 5         Spiderpig        True

# %%
union_data
# Out:
#            name    animal  age
# 0  Andy Warhowl       dog   12
# 1     Voldetort  tortoise   90
# 2       Repecka   chicken    1

# %%
titanic_data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
#Perform a left join, joins the second data set to the first
join_data = pd.merge(left=join_data1,
                     right=join_data2,
                     how="left",
                     on="name" # common column that both has
                    )
join_data
# Out:
#                name animal  age vaccinated
# 0   Catalie Portman    cat    3       True
# 1      Pico de Gato    cat    5       True
# 2         Chewbarka    dog    1      False
# 3  Sir Isaac Mewton    cat    7       True
# 4                K9    cat   11      False
# 5         Arf Vader    dog    6        NaN

# %%
# Joins the first data set to the second one
join_data = pd.merge(left=join_data1,
                     right=join_data2,
                     how="right",
                     on="name" # common column that both has
                    )
join_data
# Out:
#                name animal   age  vaccinated
# 0   Catalie Portman    cat   3.0        True
# 1      Pico de Gato    cat   5.0        True
# 2         Chewbarka    dog   1.0       False
# 3  Sir Isaac Mewton    cat   7.0        True
# 4                K9    cat  11.0       False
# 5         Spiderpig    NaN   NaN        True

# %%
#Only common things on both sets are displayed
join_data = pd.merge(left=join_data1,
                     right=join_data2,
                     how="inner",
                     on="name" # common column that both has
                    )
join_data
# Out:
#                name animal  age  vaccinated
# 0   Catalie Portman    cat    3        True
# 1      Pico de Gato    cat    5        True
# 2         Chewbarka    dog    1       False
# 3  Sir Isaac Mewton    cat    7        True
# 4                K9    cat   11       False

# %%
#Exverthing on both the joined sets is displayed
join_data = pd.merge(left=join_data1,
                     right=join_data2,
                     how="outer",
                     on="name" # common column that both has
                    )
join_data
# Out:
#                name animal   age vaccinated
# 0         Arf Vader    dog   6.0        NaN
# 1   Catalie Portman    cat   3.0       True
# 2         Chewbarka    dog   1.0      False
# 3                K9    cat  11.0      False
# 4      Pico de Gato    cat   5.0       True
# 5  Sir Isaac Mewton    cat   7.0       True
# 6         Spiderpig    NaN   NaN       True

# %% [markdown]
# # Aggregation

# %%
#Displays info in the dataset
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  home.dest  745 non-null    object
#  12  body       121 non-null    float64
#  13  boat       486 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
#Displaying all the columns
titanic_data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'home.dest', 'body', 'boat'],
#       dtype='object')

# %%
#Displays the sex
titanic_data["sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
#Counts the number of passangers by sex
titanic_data["sex"].value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
#Check survival by sex
titanic_data.groupby(["sex"])["survived"].sum()
# Out:
# sex
# female    339
# male      161
# Name: survived, dtype: int64

# %%
#Check the sum and percentage of survival by sex 
titanic_data.groupby(["sex"])["survived"].agg(["sum","mean"])
# Out:
#         sum      mean
# sex
# female  339  0.727468
# male    161  0.190985

# %% [markdown]
# # Homework
# # 1.Does the ticket fare (fare), passenger class(pclass) , family onboard(parch) affect the chances of survival

# %%
titanic_data.groupby(["survived"])["pclass"].agg(["sum","mean"])
# Out:
#            sum      mean
# survived
# 0         2023  2.500618
# 1          981  1.962000

# %%
titanic_data.groupby(["survived"])["fare"].agg(["sum","mean"])
# Out:
#                  sum       mean
# survived
# 0         18869.8951  23.353831
# 1         24680.5918  49.361184

# %%
titanic_data.groupby(["survived"])["parch"].agg(["sum","mean"])
# Out:
#           sum      mean
# survived
# 0         266  0.328801
# 1         238  0.476000

# %%
# Extract key columns
selected_data = titanic_data[['survived','sex','pclass', 'fare', 'parch']]

# Display the first few rows of the selection
print(selected_data.head())
# Out:
#    survived     sex  pclass      fare  parch
# 0         1  female       1  211.3375      0
# 1         1    male       1  151.5500      2
# 2         0  female       1  151.5500      2
# 3         0    male       1  151.5500      2
# 4         0  female       1  151.5500      2

# %%
selected_data.describe()
# Out:
#           survived       pclass         fare        parch
# count  1309.000000  1309.000000  1308.000000  1309.000000
# mean      0.381971     2.294882    33.295479     0.385027
# std       0.486055     0.837836    51.758668     0.865560
# min       0.000000     1.000000     0.000000     0.000000
# 25%       0.000000     2.000000     7.895800     0.000000
# 50%       0.000000     3.000000    14.454200     0.000000
# 75%       1.000000     3.000000    31.275000     0.000000
# max       1.000000     3.000000   512.329200     9.000000

# %%
# Set plot style
plt.style.use("ggplot")
#sns.set(style='whitegrid')

# Create a figure with 3 subplots side by side
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Survival vs Pclass
sns.barplot(x='pclass', y='survived', data=titanic_data, ax=axes[0], color="red")
axes[0].set_title('Survival Rate by Passenger Class')
axes[0].set_xlabel('Passenger Class')
axes[0].set_ylabel('Survival Rate')

# Survival vs Fare (with binning for better grouping)
titanic_data['fare_band'] = pd.qcut(titanic_data['fare'], 4)
sns.barplot(x='fare_band', y='survived', data=titanic_data, ax=axes[1], color="blue")
axes[1].set_title('Survival Rate by Fare Band')
axes[1].set_xlabel('Fare Band')
axes[1].set_ylabel('Survival Rate')
axes[1].tick_params(axis='x', rotation=45)

# Survival vs Parch
sns.barplot(x='parch', y='survived', data=titanic_data, ax=axes[2], color="green")
axes[2].set_title('Survival Rate by Family Onboard')
axes[2].set_xlabel('Number of Parents/Children')
axes[2].set_ylabel('Survival Rate')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
ax = sns.barplot(x='pclass', y='survived', data=titanic_data, color="red")
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')

# Add comment above the first bar
first_class_rate = titanic_data[titanic_data['pclass'] == 1]['survived'].mean()

ax.annotate('Highest rate',
            xy=(0, first_class_rate),
            xytext=(0, first_class_rate + 0.1),
            arrowprops=dict(facecolor='green', shrink=0.05),
            fontsize=12,
            color='darkgreen')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Day 5: Pivot Table

# %%
# Average fare by sex
titanic_pivot = titanic_data.pivot_table(values="fare", index="sex", aggfunc="mean")
titanic_pivot
# Out:
#              fare
# sex
# female  46.198097
# male    26.154601

# %%
#Creating a copy of thr new data
titanic_data_copy = titanic_data.copy()
titanic_data_copy
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
#Rename a column in the list df
titanic_data_copy.rename(columns={"sex":"gender"},inplace=True)
#Capitalizing the 1st letter of the column names using ".capitalize",".upper"-all uppercase & ".lower"-all lowercase
titanic_data_copy.columns = titanic_data_copy.columns.str.capitalize()
titanic_data_copy.columns
# Out:
# Index(['Pclass', 'Survived', 'Name', 'Gender', 'Age', 'Sibsp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Home.dest', 'Body', 'Boat',
#        'Fare_band'],
#       dtype='object')

# %%
#Using loc-location & iloc-index location for filtering/slicing data
titanic_data_copy.loc[1:13,["Cabin","Fare"]]
# Out:
#       Cabin      Fare
# 1   C22 C26  151.5500
# 2   C22 C26  151.5500
# 3   C22 C26  151.5500
# 4   C22 C26  151.5500
# 5       E12   26.5500
# 6        D7   77.9583
# 7       A36    0.0000
# 8      C101   51.4792
# 9       NaN   49.5042
# 10  C62 C64  227.5250
# 11  C62 C64  227.5250
# 12      B35   69.3000
# 13      NaN   78.8500

# %%
#Sciling a single row and displaying the output as a series
titanic_data_copy.iloc[2]
# Out:
# Pclass                                     1
# Survived                                   0
# Name            Allison, Miss. Helen Loraine
# Gender                                female
# Age                                      2.0
# Sibsp                                      1
# Parch                                      2
# Ticket                                113781
# Fare                                  151.55
# Cabin                                C22 C26
# Embarked                                   S
# Home.dest    Montreal, PQ / Chesterville, ON
# Body                                     NaN
# Boat                                     NaN
# Fare_band                  (31.275, 512.329]
# Name: 2, dtype: object

# %%
#Output of a dataframe
titanic_data_copy.iloc[[29]]
#Slicing specific rows and columns
titanic_data_copy.iloc[[0,2],[1,3]]
# Out:
#    Survived  Gender
# 0         1  female
# 2         0  female

# %%
#Finding details of a specific passenger using loc
titanic_data_copy.loc[titanic_data_copy["Name"]=="Bjornstrom-Steffansson, Mr. Mauritz Hakan",:]
#Method 2
titanic_data_copy[titanic_data_copy["Name"]=="Bjornstrom-Steffansson, Mr. Mauritz Hakan"]
# Out:
#     Pclass  Survived                                       Name Gender   Age  \
# 29       1         1  Bjornstrom-Steffansson, Mr. Mauritz Hakan   male  28.0
#
#     Sibsp  Parch  Ticket   Fare Cabin Embarked  \
# 29      0      0  110564  26.55   C52        S
#
#                              Home.dest  Body Boat         Fare_band
# 29  Stockholm, Sweden / Washington, DC   NaN    D  (14.454, 31.275]

# %%
#Sorting the data
titanic_data_copy.sort_values(by="Pclass", ascending=True)
# Out:
#       Pclass  Survived                            Name  Gender   Age  Sibsp  \
# 0          1         1   Allen, Miss. Elisabeth Walton  female  29.0      0
# 220        1         1    Ostby, Miss. Helene Ragnhild  female  22.0      0
# 219        1         1       Omont, Mr. Alfred Fernand    male   NaN      0
# 218        1         1    Oliva y Ocana, Dona. Fermina  female  39.0      0
# 217        1         0    Nicholson, Mr. Arthur Ernest    male  64.0      0
# ...      ...       ...                             ...     ...   ...    ...
# 838        3         0    Gustafsson, Mr. Johan Birger    male  28.0      2
# 839        3         0     Gustafsson, Mr. Karl Gideon    male  19.0      0
# 840        3         0             Haas, Miss. Aloisia  female  24.0      0
# 864        3         0  Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 1308       3         0              Zimmerman, Mr. Leo    male  29.0      0
#
#       Parch      Ticket      Fare Cabin Embarked  \
# ...

# %%
titanic_data_copy
# Out:
#       Pclass  Survived                                             Name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       Gender      Age  Sibsp  Parch  Ticket      Fare    Cabin Embarked  \
# ...

# %% [markdown]
# # Data visualization of the Titanic Data

# %%
#Ploting a count plot, count vs column
sns.countplot(x="Survived", data=titanic_data_copy, hue="Survived")
plt.title("Survival count")
# Out:
# Text(0.5, 1.0, 'Survival count')

# %%
#Ploting a histogram
titanic_data_copy["Fare"].hist(bins=30,color="darkgreen")
plt.title("Fare Distribution")
# Out:
# Text(0.5, 1.0, 'Fare Distribution')

# %%
titanic_data_copy["Pclass"].hist(bins=30,color="purple")
plt.title("Fare Distribution")
# Out:
# Text(0.5, 1.0, 'Fare Distribution')

# %%
#Ploting a boxplot
sns.boxplot(x="Pclass",y="Age", data=titanic_data_copy, hue="Pclass")
plt.title("Age Distribution by Class")
# Out:
# Text(0.5, 1.0, 'Age Distribution by Class')

# %%
#Ploting a heatmap to checking missing values
#cbar is displayed on the right (1-null values,0-no null vales)
sns.heatmap(titanic_data_copy.isnull(),cbar=True, cmap="viridis")
plt.title("Missing values of Heatmap")
# Out:
# Text(0.5, 1.0, 'Missing values of Heatmap')
